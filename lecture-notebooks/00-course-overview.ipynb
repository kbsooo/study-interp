# %% [markdown]
# # 00. Interp Course Overview
#
# > 이 노트북은 `/Users/kbsoo/Codes/projects/interp/` 학습 폴더의 **강의자료형 목차**다.
#
# ## 전체 코스 목표
#
# 1. Mechanistic Interpretability: 작은 transformer에서 activation/cache/hook/patching을 직접 다룬다.
# 2. Binary Reversing: 작은 binary에서 static/dynamic analysis로 로직을 복원한다.
# 3. 둘을 공통 mental model로 묶는다: **black box 내부 상태를 추적하고 intervention으로 검증하기**.

# %% [markdown]
# ## 노트북 사용법
#
# 각 강의 노트북은 아래 구조다.
#
# - **Lecture**: 개념 설명
# - **Demo**: 실행 가능한 코드
# - **Exercise**: 네가 직접 채워야 하는 TODO
# - **Checkpoint**: 완료 기준
# - **Writeup Prompt**: 노트/블로그/README로 옮길 질문
#
# 강의 보는 느낌으로 위에서 아래로 실행하되, `TODO` cell은 반드시 직접 바꿔라.

# %% [markdown]
# ## 추천 순서
#
# 1. `01-transformerlens-lecture-lab.ipynb`
# 2. 기존 `mech-interp/transformerlens.ipynb`를 위 강의 노트북 스타일로 리팩터링
# 3. `02-binary-reversing-lecture-lab.ipynb`
# 4. `notes/week-01.md` 작성
#
# ## 이번 주 산출물
#
# - [ ] TransformerLens 강의 노트북에서 top-k logits / cache shape / attention pattern / ablation 실행
# - [ ] activation patching TODO 하나 직접 완성
# - [ ] reversing 강의 노트북에서 `check.c` 컴파일/분석 실행
# - [ ] `reversing/writeups/001-simple-string-check.md` 완성

# %% [markdown]
# ## 핵심 사고방식
#
# ### Mech Interp
#
# > “이 activation/head/layer가 출력에 중요해 보인다”에서 멈추지 말고, **지우거나 바꿔서 metric이 변하는지** 확인한다.
#
# ### Binary Reversing
#
# > “Ghidra가 이렇게 보여준다”에서 멈추지 말고, **debugger로 실제 register/memory/control flow가 맞는지** 확인한다.
